# %%
# !ls
# Out:
# Chapter1.ipynb	README.md

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/python-algorithms')

# %%
os.chdir('python-algorithms')

# %%
# !git add .

# %%
from getpass import getpass

# %%
user = getpass('nxrmrz')
password = getpass('y0urc@1L1234')
os.environ['GITHUB_AUTH'] = user + ':' + password
# Out:
# nxrmrz··········
# y0urc@1L1234··········

# %%
# !git clone https://$GITHUB_AUTH@github.com/nxrmrz/python-algorithms.git
# Out:
# Cloning into 'python-algorithms'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/python-algorithms

# %%
# !ls -a
# Out:
# .git  README.md

# %%
# !git config --global user.email "nixramirez@gmail.com"
# !git config --global user.name "nxrmrz"

# %%
# !git config --get remote.origin.url
# Out:
# https://github.com/nxrmrz/python-algorithms.git

# %%
# !git commit -m "added first .ipynb notebook"
# Out:
# [main 2fc3045] added first .ipynb notebook
#  1 file changed, 1 insertion(+)
#  create mode 100644 Chapter1.ipynb

# %%
# !git config --global user.name "nxrmrz"

# %%
# !git add .

# %%
# !git commit -m "first commit"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !ls
# Out:
# README.md

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git remote add origin https://nxrmrz:@github.com/{username}/project.git

# %%
# !git push https://github.com/nxrmrz/python-algorithms
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
